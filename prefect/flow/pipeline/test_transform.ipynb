# %%
import pymongo
import pandas as pd
from dotenv import load_dotenv
import os
import logging

logging.basicConfig(level=logging.INFO)

# %%
class MongoDataExtractor:
    def __init__(self):
        """Khởi tạo và cấu hình kết nối MongoDB."""
        load_dotenv()
        self.db = self.connect_to_mongo()

    def connect_to_mongo(self):
        """Kết nối đến MongoDB."""
        mongo_uri = os.getenv('MONGO_URI')
        client = pymongo.MongoClient(mongo_uri)
        db_name = os.getenv('MONGODB_DATABASE', 'default_db_name').replace(' ', '_')
        db = client[db_name]
        return db

    def load_collection_as_dataframe(self, collection_name):
        """Lấy dữ liệu từ MongoDB và chuyển thành DataFrame."""
        collection = self.db[collection_name]
        data = list(collection.find({}))
        if not data:
            logging.warning(f"No data found in collection: {collection_name}")
            return pd.DataFrame()  
        return pd.DataFrame(data)

    def check_if_genres_processed(self):
        """Check if the movie_genres collection has been processed before."""
        return self.db['processing_flags'].find_one({'collection': 'movie_genres'}) is not None

    def mark_genres_as_processed(self):
        """Mark movie_genres as processed."""
        self.db['processing_flags'].insert_one({'collection': 'movie_genres'})

    def process_movie_genres(self, df):
        if not df.empty:
            df = df.drop(columns=['_id'])
        return df

    def process_all_collections(self):
        collections = [
            'movie_genres', 
            'movie_details', 
            'movie_reviews', 
            'movie_actor_credits', 
            'actor_details', 
            'movie_director_credits', 
            'director_details'
        ]

        transformed_data = {}

        for collection_name in collections:
            logging.info(f"Processing collection: {collection_name}")
            df = self.load_collection_as_dataframe(collection_name)

            if collection_name == 'movie_genres':
                # Check if movie_genres already processed
                if self.check_if_genres_processed():
                    logging.info(f"movie_genres already processed, skipping transformation.")
                else:
                    df = self.process_movie_genres(df)
                    self.mark_genres_as_processed()  
                    
            transformed_data[collection_name] = df

        return transformed_data

# %%
extractor = MongoDataExtractor()
transformed_data = extractor.process_all_collections()
# Out:
# INFO:root:Processing collection: movie_genres
# INFO:root:Processing collection: movie_details
# INFO:root:Processing collection: movie_reviews
# INFO:root:Processing collection: movie_actor_credits
# INFO:root:Processing collection: actor_details
# INFO:root:Processing collection: movie_director_credits
# INFO:root:Processing collection: director_details

# %%
specific_collection = 'movie_details'

if specific_collection in transformed_data:
    df = transformed_data[specific_collection]
    print(f"DataFrame for collection: {specific_collection}, Data shape: {df.shape}")
    display(df)  
    print(f"Collection '{specific_collection}' not found in transformed data.")
# Out:
# DataFrame for collection: movie_details, Data shape: (11, 27)
#                          _id  adult                     backdrop_path  \
# 0   67172d77f445c4f797c2ff5e  False  /zLj0peaxy5y2SlC6wNIQ4V0pfqg.jpg
# 1   67173cb7f1dde4dc987364a9  False  /xuvQDwrpKzjlGyDE6RxLfVSPWuI.jpg
# 2   6717ae3c7dc2bacbe37f9f98  False  /xuvQDwrpKzjlGyDE6RxLfVSPWuI.jpg
# 3   6717ae6c7dc2bacbe37f9fde  False  /qBvWwXEn3BJlNaiKUmI9ABuHkSZ.jpg
# 4   6717ae927dc2bacbe37f9ff8  False  /vzO729sITNJ1jB6Y9AJpIhlbvb2.jpg
# 5   6717aeb87dc2bacbe37fa008  False  /gn0OyRVzWGWmq4vybZOdTTRjA2N.jpg
# 6   6717aece7dc2bacbe37fa037  False                              None
# 7   6717aee27dc2bacbe37fa05c  False  /AdHbzoSlrTdHKIC3j9XNa7qJKdI.jpg
# 8   6717bfb93964419b4097fa1b  False  /xuvQDwrpKzjlGyDE6RxLfVSPWuI.jpg
# 9   6717bfd26326f18e66fd154b  False  /xuvQDwrpKzjlGyDE6RxLfVSPWuI.jpg
# 10  6717c1207e65ab09534ecfab  False  /xuvQDwrpKzjlGyDE6RxLfVSPWuI.jpg
#
#    belongs_to_collection    budget  \
# 0                   None         0
# 1                   None         0
# 2                   None         0
# 3                   None         0
# 4                   None         0
# 5                   None         0
# 6                   None         0
# 7                   None  13000000
# 8                   None         0
# 9                   None         0
# 10                  None         0
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 3                      [{'id': 27, 'name': 'Horror'}]
# 4   [{'id': 99, 'name': 'Documentary'}, {'id': 80,...
# 5                      [{'id': 35, 'name': 'Comedy'}]
# 6                      [{'id': 27, 'name': 'Horror'}]
# 7   [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 8   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 9   [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
#
#                                   homepage       id     imdb_id  \
# 0   https://www.netflix.com/title/81476885  1139829  tt28066777
# 1                                           1126475  tt27158093
# 2                                           1126475  tt27158093
# 3                                           1232645  tt26902267
# 4   https://www.netflix.com/title/81507283  1213997  tt30317302
# 5                                           1070130  tt18232550
# 6                                           1151317  tt27726037
# 7                                           1179316  tt21352916
# 8                                           1126475  tt27158093
# 9                                           1126475  tt27158093
# 10                                          1126475  tt27158093
#
#    origin_country  ... release_date revenue runtime  \
# 0            [US]  ...   2024-02-01       0      90
# 1            [GB]  ...   2024-09-19       0      92
# 2            [GB]  ...   2024-09-19       0      92
# 3            [US]  ...   2024-01-18       0     111
# 4            [US]  ...   2024-01-01       0      95
# 5        [FR, CH]  ...   2024-01-01       0      77
# 6            [US]  ...   2023-10-31       0      72
# 7            [RU]  ...   2024-01-01       0     116
# 8            [GB]  ...   2024-09-19       0      92
# 9            [GB]  ...   2024-09-19       0      92
# 10           [GB]  ...   2024-09-19       0      92
#
#                                      spoken_languages    status  \
# 0   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 5   [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 6   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 7   [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 8   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 9   [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 10  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                              tagline                      title  video  \
# 0     Hello Darkness, my new friend.         Orion and the Dark  False
# 1   Who says you're only young once?            Arthur's Whisky  False
# 2   Who says you're only young once?            Arthur's Whisky  False
# 3                                         The Vampire Next Door  False
# 4                                                     Bitconned  False
# 5                                                The Rebellious  False
# 6                                                   Spider Baby  False
# 7                                     The Bremen Town Musicians  False
# 8   Who says you're only young once?            Arthur's Whisky  False
# 9   Who says you're only young once?            Arthur's Whisky  False
# 10  Who says you're only young once?            Arthur's Whisky  False
#
#     vote_average  vote_count
# 0            6.6         480
# 1            5.5           2
# 2            5.5           2
# 3            6.4          29
# 4            6.3          43
# 5            3.5           5
# 6            0.0           0
# 7            5.9          16
# 8            5.5           2
# 9            5.5           2
# 10           5.5           2
#
# [11 rows x 27 columns]
# Collection 'movie_details' not found in transformed data.
